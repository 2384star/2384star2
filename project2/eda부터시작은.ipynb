# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
da1=pd.read_csv("./icr-identify-age-related-conditions/train.csv")

# %%
da1
# Out:
#                Id        AB          AF          AH          AM         AR
# 0    000ff2bfdfe9  0.209377  3109.03329   85.200147   22.394407   8.138688  \
# 1    007255e47698  0.145282   978.76416   85.200147   36.968889   8.138688
# 2    013f2bd269f5  0.470030  2635.10654   85.200147   32.360553   8.138688
# 3    043ac50845d5  0.252107  3819.65177  120.201618   77.112203   8.138688
# 4    044fb8a146ec  0.380297  3733.04844   85.200147   14.103738   8.138688
# ..            ...       ...         ...         ...         ...        ...
# 612  fd3dafe738fd  0.149555  3130.05946  123.763599    9.513984  13.020852
# 613  fd895603f071  0.435846  5462.03438   85.200147   46.551007  15.973224
# 614  fd8ef6377f76  0.427300  2459.10720  130.138587   55.355778  10.005552
# 615  fe1942975e40  0.363205  1263.53524   85.200147   23.685856   8.138688
# 616  ffcca4ded3bb  0.482849  2672.53426  546.663930  112.006102   8.138688
#
# ...

# %%
da_no1=da1[da1["Class"]==1]
da_no0=da1[da1["Class"]==0]

# %%
da_no1.to_csv("./icr-identify-age-related-conditions/da_no1.csv")

da_no0.to_csv("./icr-identify-age-related-conditions/sample_data/da_no1_2.numbers")

# %%
da_no0.describe()
# Out:
#                AB            AF           AH          AM          AR
# count  509.000000    509.000000   509.000000  509.000000  509.000000  \
# mean     0.416655   3181.597632   115.997626   31.292888    9.816552
# std      0.325706   1677.157950   123.507052   39.542608   11.068698
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.239288   2072.223010    85.200147   11.957517    8.138688
# 50%      0.333294   2919.819540    85.200147   19.405802    8.138688
# 75%      0.499941   4059.436260   114.923964   35.757962    8.138688
# max      4.277273  14503.256020  1910.123198  630.518230  178.943634
#
#                AX          AY          AZ          BC           BD   ...
# count  509.000000  509.000000  509.000000  509.000000    509.000000  ...  \
# mean     5.430932    0.044508   10.539383    3.377568   5194.386843  ...
# std      2.107305    0.050073    4.297309    4.484045   1497.148292  ...
# ...

# %%
da_no1.describe()
# Out:
#                AB            AF           AH          AM          AR
# count  108.000000    108.000000   108.000000  108.000000  108.000000  \
# mean     0.762256   5012.120024   131.004931   75.143672   11.597227
# std      0.812348   3783.979443   146.551293  137.717327    7.258732
# min      0.132463    192.593280    85.200147    6.073217    8.138688
# 25%      0.362137   3027.833820    85.200147   15.807862    8.138688
# 50%      0.557627   4088.147140    85.200147   30.463641    8.138688
# 75%      0.746707   5886.149967   100.031574   48.934923   11.437819
# max      6.161666  28688.187660  1237.940805  630.518230   50.253252
#
#                AX          AY          AZ           BC           BD   ...
# count  108.000000  108.000000  108.000000   108.000000    108.000000  ...  \
# mean     6.085887    0.134840   10.693998    30.088202   6085.619418  ...
# std      4.005553    0.990708    4.612481   154.139328   6422.563218  ...
# ...

# %% [markdown]
# #

# %%
da1.describe()
# Out:
#                AB            AF           AH          AM          AR
# count  617.000000    617.000000   617.000000  617.000000  617.000000  \
# mean     0.477149   3502.013221   118.624513   38.968552   10.128242
# std      0.468388   2300.322717   127.838950   69.728226   10.518877
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.252107   2197.345480    85.200147   12.270314    8.138688
# 50%      0.354659   3120.318960    85.200147   20.533110    8.138688
# 75%      0.559763   4361.637390   113.739540   39.139886    8.138688
# max      6.161666  28688.187660  1910.123198  630.518230  178.943634
#
#                AX          AY          AZ           BC           BD   ...
# count  617.000000  617.000000  617.000000   617.000000    617.000000  ...  \
# mean     5.545576    0.060320   10.566447     8.053012   5350.388655  ...
# std      2.551696    0.416817    4.350645    65.166943   3021.326641  ...
# ...

# %%
da_no1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 0 to 608
# Data columns (total 58 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      108 non-null    object
#  1   AB      108 non-null    float64
#  2   AF      108 non-null    float64
#  3   AH      108 non-null    float64
#  4   AM      108 non-null    float64
#  5   AR      108 non-null    float64
#  6   AX      108 non-null    float64
#  7   AY      108 non-null    float64
#  8   AZ      108 non-null    float64
#  9   BC      108 non-null    float64
#  10  BD      108 non-null    float64
#  11  BN      108 non-null    float64
#  12  BP      108 non-null    float64
#  13  BQ      108 non-null    float64
#  14  BR      108 non-null    float64
#  15  BZ      108 non-null    float64
#  16  CB      108 non-null    float64
#  17  CC      107 non-null    float64
#  18  CD      108 non-null    float64
#  19  CF      108 non-null    float64
#  20  CH      108 non-null    float64
# ...

# %%
da_hint=pd.read_csv("./icr-identify-age-related-conditions/greeks.csv")

# %%
da_hint=da_hint[da_hint["Alpha"]!="A"]

# %%
da_hint
# Out:
#                Id Alpha Beta Gamma Delta     Epsilon
# 0    000ff2bfdfe9     B    C     G     D   3/19/2019
# 4    044fb8a146ec     D    B     F     B   3/25/2020
# 10   06055f3f6785     D    B     F     B   6/23/2020
# 13   06c0ddf265c5     D    B     E     B   9/27/2019
# 31   0e798fd4e6e7     D    B     E     A   7/24/2020
# ..            ...   ...  ...   ...   ...         ...
# 576  ed3486389307     G    C     B     C  12/10/2018
# 585  f16b095a433f     G    C     B     C  12/10/2018
# 588  f26ee0cee841     B    B     H     A  11/12/2019
# 592  f405c0b5836f     B    C     H     C   2/13/2019
# 608  fbb79ba9d642     B    C     H     B   4/17/2019
#
# [108 rows x 6 columns]

# %%
da_hint= da_hint.drop(["Delta","Gamma","Beta","Epsilon"],axis=1)

# %%
da_hint

new_data=da_hint.merge(da_no1)

# %%
new_data
new_data.to_csv("./icr-identify-age-related-conditions/sample_data/maybe_datq.csv")

# %%
da2=da1.iloc[:,50:]

# %%
da2.describe()
# Out:
#                FS          GB           GE             GF          GH
# count  615.000000  617.000000   617.000000     617.000000  617.000000  \
# mean     0.421501   20.724856   131.714987   14679.595398   31.489716
# std      1.305365    9.991907   144.181524   19352.959387    9.864239
# min      0.067730    4.102182    72.611063      13.038894    9.432735
# 25%      0.067730   14.036718    72.611063    2798.992584   25.034888
# 50%      0.250601   18.771436    72.611063    7838.273610   30.608946
# 75%      0.535067   25.608406   127.591671   19035.709240   36.863947
# max     31.365763  135.781294  1497.351958  143790.071200   81.210825
#
#                GI          GL       Class
# count  617.000000  616.000000  617.000000
# mean    50.584437    8.530961    0.175041
# std     36.266251   10.327010    0.380310
# min      0.897628    0.001129    0.000000
# 25%     23.011684    0.124392    0.000000
# 50%     41.007968    0.337827    0.000000
# ...
